# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# !pip install webdriver_manager

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import requests
import pandas as pd

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com

# %%
# Create a Beautiful Soup object

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
url = 'https://redplanetscience.com/'
browser.visit(url)
html =browser.html
mars_soup = soup(html, 'html.parser')
mars_soup
# Out:
# <html><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet" type="text/css"/>
# <link href="css/app.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
# <title>News - Mars Exploration Program</title>
# </head>
# <body>
# <div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# ...

# %%
text_elements = mars_soup.find_all("div", class_="list_text")

# %%
# Create an empty list to store the dictionaries
Listof_titles = []
for title in text_elements:
    resume = {}
    Main = title.find('div', class_="content_title").text
    sumary = title.find('div', class_="article_teaser_body").text
    resume["Main"]= Main
    resume["sumary"]= sumary
    Listof_titles.append(resume)
Listof_titles
# Out:
# [{'Main': "NASA's Mars 2020 Rover Tests Descent-Stage Separation",
#   'sumary': "A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft."},
#  {'Main': "NASA's Perseverance Rover Will Peer Beneath Mars' Surface ",
#   'sumary': "The agency's newest rover will use the first ground-penetrating radar instrument on the Martian surface to help search for signs of past microbial life. "},
#  {'Main': "NASA's Briefcase-Size MarCO Satellite Picks Up Honors",
#   'sumary': 'The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.'},
#  {'Main': "Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch",
#   'sumary': "A NASA Wallops Flight Facility cargo plane transported more than two tons of equipment — including the rover's sample collection tubes — to Florida for this summer's liftoff."},
# ...

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
# Loop through the text elements
# Extract the title and preview text from the elements
# Store each title and preview pair in a dictionary
# Add the dictionary to the list

# %%
# Create an empty list to store the dictionaries
Listof_titles = []
for title in text_elements:

    Listof_titles.append(summary)
Listof_titles
# Out:
# [{'titleVF': [<div class="content_title">NASA's Mars 2020 Rover Tests Descent-Stage Separation</div>,
#    <div class="content_title">NASA's Perseverance Rover Will Peer Beneath Mars' Surface </div>,
#    <div class="content_title">NASA's Briefcase-Size MarCO Satellite Picks Up Honors</div>,
#    <div class="content_title">Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch</div>,
#    <div class="content_title">Q&amp;A with the Student Who Named Ingenuity, NASA's Mars Helicopter</div>,
#    <div class="content_title">The Extraordinary Sample-Gathering System of NASA's Perseverance Mars Rover</div>,
#    <div class="content_title">5 Hidden Gems Are Riding Aboard NASA's Perseverance Rover</div>,
#    <div class="content_title">MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss</div>,
#    <div class="content_title">NASA's Treasure Map for Water Ice on Mars</div>,
# ...

# %%
# Print the list to confirm success
Listof_titles = pd.DataFrame(Listof_titles)
Listof_titles
# Out:
#                                                  Main  \
# 0   NASA's Mars 2020 Rover Tests Descent-Stage Sep...
# 1   NASA's Perseverance Rover Will Peer Beneath Ma...
# 2   NASA's Briefcase-Size MarCO Satellite Picks Up...
# 3   Air Deliveries Bring NASA's Perseverance Mars ...
# 4   Q&A with the Student Who Named Ingenuity, NASA...
# 5   The Extraordinary Sample-Gathering System of N...
# 6   5 Hidden Gems Are Riding Aboard NASA's Perseve...
# 7   MAVEN Maps Electric Currents around Mars that ...
# 8           NASA's Treasure Map for Water Ice on Mars
# 9              Mars 2020 Stands on Its Own Six Wheels
# 10  Newfound Martian Aurora Actually the Most Comm...
# 11  NASA, ULA Launch Mars 2020 Perseverance Rover ...
# 12  All About the Laser (and Microphone) Atop Mars...
# 13           NASA's Mars Rover Drivers Need Your Help
# 14  NASA's Mars Perseverance Rover Gets Its Sample...
#
#                                                sumary
# ...

# %%
browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON
Listof_titles.to_json("Marsnewspt1_df.json")
print(Listof_titles.to_json())
# Out:
# {"Main":{"0":"NASA's Mars 2020 Rover Tests Descent-Stage Separation","1":"NASA's Perseverance Rover Will Peer Beneath Mars' Surface ","2":"NASA's Briefcase-Size MarCO Satellite Picks Up Honors","3":"Air Deliveries Bring NASA's Perseverance Mars Rover Closer to Launch","4":"Q&A with the Student Who Named Ingenuity, NASA's Mars Helicopter","5":"The Extraordinary Sample-Gathering System of NASA's Perseverance Mars Rover","6":"5 Hidden Gems Are Riding Aboard NASA's Perseverance Rover","7":"MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss","8":"NASA's Treasure Map for Water Ice on Mars","9":"Mars 2020 Stands on Its Own Six Wheels","10":"Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate","11":"NASA, ULA Launch Mars 2020 Perseverance Rover Mission to Red Planet","12":"All About the Laser (and Microphone) Atop Mars 2020, NASA's Next Rover","13":"NASA's Mars Rover Drivers Need Your Help","14":"NASA's Mars Perseverance Rove
# ...
